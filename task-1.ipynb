# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import os

# Dataset path
base_path = r'C:\Users\rushd\OneDrive\Documents\leetcode'

# Load preprocessed data
print("Loading preprocessed MNIST dataset...")
X_train_scaled = np.load(os.path.join(base_path, 'X_train_scaled.npy'))
y_train = np.load(os.path.join(base_path, 'y_train.npy'))
X_val = np.load(os.path.join(base_path, 'X_val.npy'))
y_val = np.load(os.path.join(base_path, 'y_val.npy'))
X_test_scaled = np.load(os.path.join(base_path, 'X_test_scaled.npy'))
y_test = np.load(os.path.join(base_path, 'y_test.npy'))

print("✅ Data loaded successfully!")
print(f"\nDataset shapes:")
print(f"  X_train: {X_train_scaled.shape}")
print(f"  y_train: {y_train.shape}")
print(f"  X_val: {X_val.shape}")
print(f"  y_val: {y_val.shape}")
print(f"  X_test: {X_test_scaled.shape}")
print(f"  y_test: {y_test.shape}")

# Data exploration
print(f"\nData statistics:")
print(f"  Feature range: [{X_train_scaled.min():.4f}, {X_train_scaled.max():.4f}]")
print(f"  Feature mean: {X_train_scaled.mean():.6f}")
print(f"  Feature std: {X_train_scaled.std():.6f}")

# Label distribution
unique, counts = np.unique(y_train, return_counts=True)
print(f"\nTraining label distribution:")
for label, count in zip(unique, counts):
    print(f"  Digit {label}: {count} samples")
# Out:
# Loading preprocessed MNIST dataset...
# ✅ Data loaded successfully!
#
# Dataset shapes:
#   X_train: (48000, 784)
#   y_train: (48000,)
#   X_val: (12000, 784)
#   y_val: (12000,)
#   X_test: (10000, 784)
#   y_test: (10000,)
#
# Data statistics:
#   Feature range: [-1.2742, 244.9469]
#   Feature mean: 0.000433
#   Feature std: 0.956243
#
# Training label distribution:
#   Digit 0: 4738 samples
#   Digit 1: 5394 samples
#   Digit 2: 4766 samples
#   Digit 3: 4905 samples
#   Digit 4: 4674 samples
#   Digit 5: 4337 samples
#   Digit 6: 4734 samples
#   Digit 7: 5012 samples
#   Digit 8: 4681 samples
#   Digit 9: 4759 samples
#   Feature std: 0.956243
#
# Training label distribution:
#   Digit 0: 4738 samples
#   Digit 1: 5394 samples
#   Digit 2: 4766 samples
#   Digit 3: 4905 samples
#   Digit 4: 4674 samples
#   Digit 5: 4337 samples
#   Digit 6: 4734 samples
#   Digit 7: 5012 samples
#   Digit 8: 4681 samples
#   Digit 9: 4759 samples
